# %% [markdown]
# 1. Algorithm to find the factorial of a number:
#
# Algorithm Factorial(n)
#
# Input: A non-negative integer n
#
# Output: The factorial of n
#
# 1.  If n < 0 then
# 2.      return "Factorial is not defined for negative numbers"
# 3.  Else if n = 0 then
# 4.      return 1
# 5.  Else
# 6.      factorial = 1
# 7.      for i = 1 to n do
# 8.          factorial = factorial * i
# 9.      return factorial
# 2. Algorithm to display the first n natural numbers:
#
# Algorithm DisplayNaturalNumbers(n)
#
# Input: A positive integer n
#
# Output: Displays the first n natural numbers
#
# 1.  If n <= 0 then
# 2.      return "Input must be a positive integer"
# 3.  Else
# 4.      for i = 1 to n do
# 5.          print i
# 3. Algorithm to find the sum of the first n natural numbers:
#
# Algorithm SumOfNaturalNumbers(n)
#
# Input: A positive integer n
#
# Output: The sum of the first n natural numbers
#
# 1.  If n <= 0 then
# 2.      return "Input must be a positive integer"
# 3.  Else
# 4.      sum = 0  // Initialize sum
# 5.      for i = 1 to n do
# 6.          sum = sum + i
# 7.      return sum
#
# // Alternatively, you can use the formula for a more efficient solution:
# // 1. If n <= 0 then
# // 2.    return "Input must be a positive integer"
# // 3. Else
# // 4.  return n * (n + 1) / 2
# 4. Algorithm to find the first n odd natural numbers:
#
# Algorithm FirstNOddNumbers(n)
#
# Input: A positive integer n
#
# Output: Displays the first n odd natural numbers
#
# 1.  If n <= 0 then
# 2.      return "Input must be a positive integer"
# 3.  Else
# 4.      for i = 1 to n do
# 5.          odd_number = 2 * i - 1
# 6.          print odd_number
